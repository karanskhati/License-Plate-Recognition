# %%
import cv2
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/mosaic_2/Ripped_Jaws
# Out:
# /content/gdrive/.shortcut-targets-by-id/1CsVUrWgt-9XXwwCwQrT6ohSYOEalQ9Qv/mosaic_2/Ripped_Jaws

# %%
import beijing
from google.colab.patches import cv2_imshow

# %%
from IPython.display import clear_output, Image

# %%
cap=cv2.VideoCapture('/content/WhatsApp Video 2020-12-03 at 6.18.28 PM_Trim.mp4')
ret=True

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open(‘video.mp4’,‘rb’).read()
data_url = “data:video/mp4;base64,” + b64encode(mp4).decode()
HTML("https://youtu.be/d_HlPboLRL8"% data_url)
# Out:
#   File "<ipython-input-11-f2faea62dbb5>", line 3
#     mp4 = open(‘video.mp4’,‘rb’).read()
#                     ^
# SyntaxError: invalid character in identifier

# %%
while ret:
    ret,img=cap.read()
    clear_output(wait=True)
    if ret:
      cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F6B40A17310>
